# %% [markdown]
# # <font>2.1. Regressão Linear Simples</font>
# ---
#
# <img src="https://selecao.letscode.com.br/favicon.png" width="40px" style="position: absolute; top: 15px; right: 20px; border-radius: 5px;" />
#
# ## Roteiro da Aula
#
# 1. Correlação vs Regressão Linear
# 2. Regressão Linear: Conceitos Iniciais
# 3. Entendendo a regressão linear na prática
# 4. Como encontrar a reta de regressão ideal? (Minimizando o erro)
# 5. Exemplo prático: Peso e Altura
#     - Conhecendo as bibliotecas: `sklearn` e `statsmodels`
#     - Modelo com a presença de outliers
# 6. Características do Erro
# 7. Métricas para Análise dos Erros
#
# ---
#
# ## 1. Correlação vs Regressão Linear
#
# ### O que é correlação?
#
# Trata-se de uma medida da relação entre diferentes variáveis. Os coeficientes de correlação auxiliam os pesquisadores a mensurar essa relação. Os coeficientes de correlação são métodos estatísticos para se medir as relações entre variáveis e o que elas representam.
#
# O que a correlação procura entender é como uma variável se comporta em um cenário onde outra está variando, visando identificar se existe alguma relação entre a variabilidade de ambas. Embora não implique em causalidade, o coeficiente de correlação exprime em números essa relação, ou seja, quantifica a relação entre as variáveis.
#
# <img style="border-radius: 10px" src="https://i0.wp.com/www.abgconsultoria.com.br/blog/wp-content/uploads/img1-2.png?w=1500" style="display: block; margin: 2rem  auto;" />
#
# Mas não existe apenas uma forma de se calcular a correlação entre variáveis. Dependendo da forma e de como se comportam as variáveis, um coeficiente de correlação é mais adequado que outro.
#
# ### Coeficiente de Correlação de Pearson
# O coeficiente de correlação de Pearson (r), também chamado de correlação linear ou r de Pearson, é um grau de relação entre duas variáveis quantitativas e exprime o grau de correlação através de valores situados entre -1 e 1.
#
# Quando  o coeficiente de correlação se aproxima de 1, nota-se um aumento no valor de uma variável quando a outra também aumenta, ou seja, há uma relação linear positiva. Quando o coeficiente se aproxima de -1, também é possível dizer que as variáveis são correlacionadas, mas nesse caso quando o valor de uma variável aumenta o da outra diminui. Isso é o que é chamado de correlação negativa ou inversa.
#
# Um coeficiente de correlação próximo de zero indica que não há relação entre as duas variáveis, e quanto mais eles se aproximam de 1 ou  -1, mais forte é a relação.
#
# <img style="border-radius: 10px" src="https://i0.wp.com/www.abgconsultoria.com.br/blog/wp-content/uploads/img2-2.png?w=1500" />
#
# ### Coeficiente de Correlação de Spearman
# Denominado pela letra grega rho (ρ), o coeficiente de correlação de postos de Spearman é uma medida de correlação não paramétrica também avaliado no intervalo entre -1 e 1.
#
# Ao contrário do coeficiente de Pearson, o coeficiente de Spearman não exige a suposição de que a relação entre as variáveis seja linear, nem requer que as mesmas sejam quantitativas – pode inclusive ser utilizado para verificar relação entre variáveis medidas no nível ordinal.
#
# ### Coeficiente de Correlação de Kendall
# Expresso pela letra grega tau (τ), o coeficiente de correlação de Kendall é uma medida de associação para variáveis ordinais. Uma vantagem de tau sobre o coeficiente de Spearman é a possibilidade de ser generalizado para um coeficiente de correlação parcial.
#
#
# <img style="display: block; margin: 2rem  auto; width: 400px; height: 600px; object-fit: cover; object-position: 0px 112%; border-radius: 10px" src="https://escoladedados.org/wp-content/uploads/2021/07/correlacao.png">
#
#
# <div style="display: flex; justify-content: center;">
#
# | Correlação | Regressão |
# |:----------:|:---------:|
# | Mede o grau de relação entre duas variáveis | Uma variável afeta a outra |
# | Grau de interelação | Baseada na causalidade (Causa e efeito) |
# | $\rho(x,y)$ = $\rho(y,x)$ | Unidirecional |
# | Único ponto | Linha |
#
# </div>
#
# ### Correlação não implica em causalidade!
#
# Dizer que Correlação não implica em Causalidade, quer dizer que duas coisas correlacionadas não implicam, necessariamente, no fato de uma ser causa da outra. Um exemplo palpável que cabe bem à situação seria a seguinte afirmativa: em países do hemisfério norte nota-se que as pessoas tendem a gastar mais em compras no frio.
#
# Apesar do gasto em compras estar correlacionado negativamente com a temperatura (- temperatura, + compras), não quer dizer que o frio cause um aumento nas vendas. Uma explicação mais plausível para esse constatado é que datas festivas — como o Natal, por exemplo — coincidem com épocas de frio nos países situados ao norte da Linha do Equador.
#
#
# > [Link para os slides](https://docs.google.com/presentation/d/1zs6WbS1VQDykVvi3rduVnlG_NTlH9V3Q/edit?usp=sharing&ouid=100697162582615560133&rtpof=true&sd=true)

# %%
# Importação das bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

sns.set()
pio.templates.default = 'plotly_dark'

# %% [markdown]
# ## 2. Regressão Linear: Conceitos iniciais
#
# Vejamos a importância da escolha do coeficiente ideal na prática...

# %%
# Criando um exemplo simples
x = np.arange(6)

# %%
x
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
y = x

# %%
# Visualizando os dados

plt.scatter(x, y)

# %%
# beta1 = 1
# beta0 = 0

# %% [markdown]
# ### Equação da reta de regressão
#
# $$
# y = \beta_1x + \beta_0 = ax + b
# $$
#
# - $\beta_1$: coeficiente que multiplica a variável independente
# - $\beta_0$: intercepto

# %%
b0 = 0 # Beta0, que já sabemos que é igual a zero

# %%
# Visualizando diferentes retas de regressão para diferentes

plt.figure(figsize=(14,8))
plt.scatter(x, y) # Dados originais

coeficiente_erro = [] # Primeiro elemento vai ser o valor do coeficiente, e o segundo elemento vai ser o erro associado a ele

# Fazendo o coeficiente beta1 variar
for b1 in range(-3, 6):
  y_estimado = b0 + b1*x # Isso gera um array

  plt.plot(x, y_estimado, label=f'$\\beta_1 = {b1}$')

  erro = y - y_estimado

  SQE = sum(erro**2) # Soma quadrática dos erros

  coeficiente_erro.append([b1, SQE])

plt.legend(fontsize=12)
plt.title('Diferentes retas de regressão para diferentes valores de $\\beta_1$', fontsize=16, fontweight='bold')
plt.xlabel('x')
plt.ylabel('$y_{estimado}$')
plt.show()

# %% [markdown]
# No nosso caso, $y = x$, então, $\beta_0 = 0$, $\beta_1 = 1$.

# %%
coeficiente_erro
# Out:
# [[-3, 880],
#  [-2, 495],
#  [-1, 220],
#  [0, 55],
#  [1, 0],
#  [2, 55],
#  [3, 220],
#  [4, 495],
#  [5, 880]]

# %%
erros = np.array(coeficiente_erro)

# %%
erros
# Out:
# array([[ -3, 880],
#        [ -2, 495],
#        [ -1, 220],
#        [  0,  55],
#        [  1,   0],
#        [  2,  55],
#        [  3, 220],
#        [  4, 495],
#        [  5, 880]])

# %%
erros[:,0]
# Out:
# array([-3, -2, -1,  0,  1,  2,  3,  4,  5])

# %%
plt.scatter(erros[:,0], erros[:,1])

# %% [markdown]
# ### Calculando os coeficientes $\beta_0$ e $\beta_1$ por meio das equações
#
# $$
# \beta_1 = \frac{\sum_{i=1}^N (x_i - \bar{x}) \cdot (y_i - \bar{y})}{\sum_{i=1}^N (x_i - \bar{x})^2}
# $$
#
# $$
# \beta_0 = \bar{y} - \beta_1\bar{x}
# $$

# %%
x
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
y
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
x_mean = x.mean()
y_mean = y.mean()

# %%
x_mean, y_mean
# Out:
# (2.5, 2.5)

# %%
# Calculando o beta1

num = (x - x_mean) * (y - y_mean)
den = (x - x_mean)**2

# %%
beta1 = sum(num) / sum(den)

# %%
beta0 = y_mean - beta1 * x_mean

# %%
beta0
# Out:
# 0.0

# %% [markdown]
# ## Regressão Linear Simples: Altura $\Rightarrow$ Peso

# %%
df = pd.read_csv('https://s3-sa-east-1.amazonaws.com/lcpi/28c52b9b-6c44-406b-9f67-a297e1193365.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ### Conversão das unidades

# %%
# Conversão de polegadas para cm
df['altura'] = df['Height'] * 2.54

# %%
# Conversão de libras para kg
df['peso'] = df['Weight'] * 0.453592

# %%
df.head()
# Out:
#   Gender     Height      Weight      altura        peso
# 0   Male  73.847017  241.893563  187.571423  109.720985
# 1   Male  68.781904  162.310473  174.706036   73.622732
# 2   Male  74.110105  212.740856  188.239668   96.497550
# 3   Male  71.730978  220.042470  182.196685   99.809504
# 4   Male  69.881796  206.349801  177.499761   93.598619

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
#  3   altura  10000 non-null  float64
#  4   peso    10000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 390.8+ KB

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.describe()
# Out:
#              Height        Weight        altura          peso
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      66.367560    161.440357    168.573602     73.228054
# std        3.847528     32.108439      9.772721     14.564131
# min       54.263133     64.700127    137.828359     29.347460
# 25%       63.505620    135.818051    161.304276     61.605982
# 50%       66.318070    161.212928    168.447898     73.124894
# 75%       69.174262    187.169525    175.702625     84.898599
# max       78.998742    269.989699    200.656806    122.465167

# %% [markdown]
# ### Visualização gráfica

# %%
px.scatter(df, x='altura', y='peso', width=800, height=600, marginal_x='histogram', marginal_y='histogram')
# Out:
# <div>                            <div id="4810ccc5-e943-4a49-84d4-3ee4c4047c2f" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4810ccc5-e943-4a49-84d4-3ee4c4047c2f")) {                    Plotly.newPlot(                        "4810ccc5-e943-4a49-84d4-3ee4c4047c2f",                        [{"hovertemplate":"altura=%{x}<br>peso=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[187.57142322448811,174.70603627656138,188.23966769513365,182.19668514447775,177.49976148723286,170.8226598470285,174.71410637922045,173.60522939943328,170.22813214372283,161.17949470505067,180.83627099875525,181.96764500282032,164.50647599885,175.9789980456698,175.87907986372045,171.81987403906984,183.942524230009,162.49478733149493,176.88575214537084,172.55745232918412,172.50422749230435,176.37617726482034,168.01879518063035,191.02317298012184,172.4487187000549,173.08584330743003,175.48766382947102,184.91414253191076,171.24995539556042,173.98089500648203,174.29000079752274,188.04587135903623,181.6816687303501,175.71760919290577,176.7260940081211,178.81835937672955,175.45347476554045,170.6715491381159,167.15058176352375,163.3326372445611,172.65481401707962,183.36114193640202,165.7866776310601,167.86905053573216,171.47621664991306,178.06615708809903,173.35966455980267,183.31868115412516,175.7168383519486,185.0907147739769,164.54776076408726,178.26621671420858,173.96828364246608,171.02031043778115,170.15699796960894,168.90885674663477,173.61676388185296,179.7671260388094,180.88844612045608,177.8339479866312,181.3640828407276,176.66209294087304,187.49907777673553,170.172082190715,181.40290336845038,165.80942253087093,173.41644634454013,184.8240396637097,172.97242469288085,174.99763342330976,175.99535530679523,179.12899028957952,176.94586207535545,171.6919827721059,184.17062576546343,180.98258343367382,182.39533469899166,183.5027203172998,168.94207425877414,167.71374637223823,171.6459710145469,173.34628424812547,187.51836258668223,177.29825947564564,167.53732757364295,180.54070464239254,169.15433920450758,175.13689913577448,173.34093295245825,183.68473581202682,182.41116794180826,165.70210577785005,179.42694643045218,164.4190910170277,170.44302000331504,165.39841161563606,182.12113441846498,169.7555106430556,168.83703916425623,176.3052766003339,177.93253078529222,169.52875581598627,168.33679595315257,173.5542579020041,177.99275601589463,174.5817898977854,171.59237020516503,168.284226638376,175.72279480866203,171.72712655176483,176.00355457559223,173.20433737956765,181.88199792918212,175.760018076242,170.84538088681722,187.1603912359995,176.62452611852882,173.51136199732946,172.05696720475584,182.13263700679425,161.62595209361822,174.55184407744372,170.0513277914747,159.27575392770365,183.53635866594223,180.1079787791757,171.72900274827228,179.83595974746328,176.03411337448668,168.25696178653445,171.43017016227572,167.14787066005033,181.4670123803187,173.89959078867784,162.5293284966492,180.34482012204785,173.07489944908338,173.72431663022735,172.96439815234191,173.0770995040391,174.90462938420796,168.01808545726598,168.16332141451562,171.27758534530702,176.4566093193674,179.11028362363936,181.19947514148774,180.34493970907866,168.15396317393342,184.2599998952873,171.3975534654244,165.99004281175817,179.94391854905604,177.64372715865045,164.43913132680018,176.04334331619975,174.84969566407588,157.32080109991458,174.22707225919999,165.6551819683161,163.40746619174064,174.6222230224191,184.12372471703657,170.77418453236794,170.84955630188296,165.40100087926066,168.3075628969345,171.96226633545336,166.44796775540533,177.46718331537843,173.94396342642182,183.42346689812754,173.17601304294362,182.83226461889106,167.80544730113522,169.3066569913 ...

# %%
plt.style.use('seaborn')

# %%
sns.jointplot(data=df, x='altura', y='peso', kind='reg', joint_kws={'line_kws':{'color':'red'}})

# %%
sns.lmplot(data=df, x='altura', y='peso', hue='Gender')

# %%
sns.histplot(df['altura'], kde=True)
# Out:
# <AxesSubplot:xlabel='altura', ylabel='Count'>

# %%
sns.histplot(df['peso'], kde=True)
# Out:
# <AxesSubplot:xlabel='peso', ylabel='Count'>

# %%
sns.histplot(data=df, x='peso', kde=True, hue='Gender')
# Out:
# <AxesSubplot:xlabel='peso', ylabel='Count'>

# %% [markdown]
# ### Calculando a correlação entre as features

# %%
from scipy.stats import pearsonr

# %% [markdown]
# - $H_0$: Os nossos dados não possuem uma correlação forte
# - $H_1$: Os nossos dados **possuem** uma correlação forte

# %%
correlacao, p_value = pearsonr(df['altura'], df['peso'])

if p_value <= 0.05:
  print('Rejeita a hipótese H0, ou seja, os nossos dados possuem uma correlação alta')
else:
  print('Aceita H0, ou seja, os nossos dados NÃO possuem uma correlação alta')

print(f'O valor da correlação é {correlacao}')
# Out:
# Rejeita a hipótese H0, ou seja, os nossos dados possuem uma correlação alta
# O valor da correlação é 0.9247562987409148

# %%
correlacao
# Out:
# 0.9247562987409148

# %%
df.corr()
# Out:
#           Height    Weight    altura      peso
# Height  1.000000  0.924756  1.000000  0.924756
# Weight  0.924756  1.000000  0.924756  1.000000
# altura  1.000000  0.924756  1.000000  0.924756
# peso    0.924756  1.000000  0.924756  1.000000

# %% [markdown]
# - Correlação muito forte: [-1, -0.8] or [0.8, 1]

# %% [markdown]
# ### Separando variáveis

# %%
# Variável de entrada
X = df['altura']

# Variável de saída
y = df['peso']

# %% [markdown]
# ### Calculando os coeficientes da RL para os nossos dados
#
# $$
# \beta_1 = \sum_{i=1}^N \frac{(x_i - \bar{x}) \cdot (y_i - \bar{y})}{(x_i - \bar{x})^2}
# $$
#
# $$
# \beta_0 = \bar{y} - \beta_1\bar{x}
# $$

# %%
x_mean = X.mean()
y_mean = y.mean()

# %%
x_mean, y_mean
# Out:
# (168.57360177724604, 73.22805433651767)

# %%
# Calculando o beta1

num = (X - x_mean) * (y - y_mean)
den = (X - x_mean)**2

# %%
beta1 = sum(num) / sum(den)

# %%
beta1
# Out:
# 1.3781495809287978

# %%
beta0 = y_mean - beta1 * x_mean

# %%
beta0
# Out:
# -159.091584308452

# %%
# Coeficientes
beta0, beta1
# Out:
# (-159.091584308452, 1.3781495809287978)

# %%
y_est = beta0 + beta1 * X

# %%
plt.scatter(X, y, label='Valores verdadeiros')
plt.scatter(X, y_est, c='red', alpha=0.1, label='Valores estimados')

plt.legend(fontsize=12)

# %%
x_0_200 = np.arange(201)

y_est_exemplo = beta0 + beta1 * x_0_200

plt.scatter(X, y) # Plotando os dados originais
plt.scatter(x_0_200, y_est_exemplo, c='red', linewidth=2)

# %%
# y_est = -159.09 + 1.38 * x

# %% [markdown]
# ### Scikit Learn

# %%
# !pip install sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
X.values
# Out:
# array([187.57142322, 174.70603628, 188.2396677 , ..., 162.22470022,
#        175.34697755, 157.33838453])

# %%
X.values.reshape(-1, 1)
# Out:
# array([[187.57142322],
#        [174.70603628],
#        [188.2396677 ],
#        ...,
#        [162.22470022],
#        [175.34697755],
#        [157.33838453]])

# %%
lr.fit(X.values.reshape(-1, 1), y.values) # Treinando o nosso modelo, ou seja, calculando os coeficientes da regressão
# Out:
# LinearRegression()

# %%
lr.coef_ # Obtendo o valor do beta1
# Out:
# array([1.37814958])

# %%
lr.intercept_
# Out:
# -159.09158430845076

# %%
lr.predict(X.values.reshape(-1, 1))
# Out:
# array([ 99.409894  ,  81.67946637, 100.33083484, ...,  64.47831832,
#         82.56277932,  57.7442444 ])

# %%
lr.predict([[171], [180], [100]])
# Out:
# array([ 76.57199403,  88.97534026, -21.27662622])

# %%
-159 + 1.38 * 100
# Out:
# -21.0

# %% [markdown]
# ---

# %% [markdown]
# ### Statsmodels

# %%
# !pip install statsmodels

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(X)

model = sm.OLS(y, x).fit()
# Out:
# C:\Users\Gartarok\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning:
#
# In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   peso   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                 5.904e+04
# Date:                Wed, 16 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:48:53   Log-Likelihood:                -31313.
# No. Observations:               10000   AIC:                         6.263e+04
# Df Residuals:                    9998   BIC:                         6.265e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -159.0916      0.958   -166.109      0.000    -160.969    -157.214
# altura         1.3781      0.006    242.975      0.000       1.367       1.389
# ==============================================================================
# Omnibus:                        2.141   Durbin-Watson:                   1.677
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                2.150
# Skew:                           0.036   Prob(JB):                        0.341
# Kurtosis:                       2.991   Cond. No.                     2.92e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model.resid # Resíduos da regressão
# Out:
# 0       10.311091
# 1       -8.056735
# 2       -3.833285
# 3        7.806803
# 4        8.068981
#           ...
# 9995   -10.504621
# 9996     1.827329
# 9997    -6.202942
# 9998    -8.240614
# 9999    -6.193921
# Length: 10000, dtype: float64

# %%
plt.scatter(df['peso'], model.resid)

# %% [markdown]
# ## Influência dos Outliers

# %%
X = df['altura'].values
y = df['peso'].values

# %% [markdown]
# ### Obtendo apenas 100 amostras (como array)

# %%
X = X[:100]
y = y[:100]

# %%
X_outliers = np.append(X, [150, 140, 173])
y_outliers = np.append(y, [200, 100, 250])

# %%
# Plotando os dados sem outliers
plt.scatter(X, y)

# %%
# Plotando os dados COM outliers
plt.scatter(X_outliers, y_outliers)

# %% [markdown]
# ### Modelo sem a presença dos outliers

# %%
lr = LinearRegression()

# %%
lr.fit(X.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([1.04495271])

# %%
lr.intercept_
# Out:
# -98.52075866207376

# %%
y_est = lr.predict(X.reshape(-1, 1))

# %%
y[:5]
# Out:
# array([109.72098511,  73.62273185,  96.49755015,  99.80950419,
#         93.59861876])

# %%
y_est[:5]
# Out:
# array([97.48250832, 84.03878736, 98.18079219, 91.8661612 , 86.95809809])

# %% [markdown]
# ### Modelo com a presença dos outliers

# %%
lr_outliers = LinearRegression()

# %%
lr_outliers.fit(X_outliers.reshape(-1, 1), y_outliers)
# Out:
# LinearRegression()

# %%
lr_outliers.coef_
# Out:
# array([0.13487779])

# %%
lr_outliers.intercept_
# Out:
# 64.05035131391783

# %%
y_est_outliers = lr_outliers.predict(X_outliers.reshape(-1,1))

# %%
y[:5]
# Out:
# array([109.72098511,  73.62273185,  96.49755015,  99.80950419,
#         93.59861876])

# %%
y_est_outliers[:5]
# Out:
# array([89.34956993, 87.614315  , 89.43970127, 88.62463715, 87.99112648])

# %% [markdown]
# ### Analisando as diferenças entre os modelos sem e com outliers

# %%
plt.scatter(X, y)
plt.plot(X, y_est, color='green')

# %%
plt.scatter(X_outliers, y_outliers)
plt.plot(X_outliers, y_est_outliers, color='green')

# %%
X_outliers
# Out:
# array([187.57142322, 174.70603628, 188.2396677 , 182.19668514,
#        177.49976149, 170.82265985, 174.71410638, 173.6052294 ,
#        170.22813214, 161.17949471, 180.836271  , 181.967645  ,
#        164.506476  , 175.97899805, 175.87907986, 171.81987404,
#        183.94252423, 162.49478733, 176.88575215, 172.55745233,
#        172.50422749, 176.37617726, 168.01879518, 191.02317298,
#        172.4487187 , 173.08584331, 175.48766383, 184.91414253,
#        171.2499554 , 173.98089501, 174.2900008 , 188.04587136,
#        181.68166873, 175.71760919, 176.72609401, 178.81835938,
#        175.45347477, 170.67154914, 167.15058176, 163.33263724,
#        172.65481402, 183.36114194, 165.78667763, 167.86905054,
#        171.47621665, 178.06615709, 173.35966456, 183.31868115,
#        175.71683835, 185.09071477, 164.54776076, 178.26621671,
#        173.96828364, 171.02031044, 170.15699797, 168.90885675,
#        173.61676388, 179.76712604, 180.88844612, 177.83394799,
#        181.36408284, 176.66209294, 187.49907778, 170.17208219,
#        181.40290337, 165.80942253, 173.41644634, 184.82403966,
#        172.97242469, 174.99763342, 175.99535531, 179.12899029,
#        176.94586208, 171.69198277, 184.17062577, 180.98258343,
#        182.3953347 , 183.50272032, 168.94207426, 167.71374637,
#        171.64597101, 173.34628425, 187.51836259, 177.29825948,
#        167.53732757, 180.54070464, 169.1543392 , 175.13689914,
#        173.34093295, 183.68473581, 182.41116794, 165.70210578,
#        179.42694643, 164.41909102, 170.44302   , 165.39841162,
#        182.12113442, 169.75551064, 168.83703916, 176.3052766 ,
#        150.        , 140.        , 173.        ])

# %%
plt.figure(figsize=(18, 8))

plt.subplot(1, 2, 1)
plt.scatter(X, y)
plt.plot(X, y_est, color='green', label='Sem outliers')
plt.plot(X, lr_outliers.predict(X.reshape(-1,1)), color='red', label='Com outliers')
# plt.xlim(140, 200)
# plt.ylim(40, 250)
plt.title('Considerando apenas os dados "dentro do padrão"')
plt.legend(fontsize=12)

plt.subplot(1, 2, 2)
plt.scatter(X_outliers, y_outliers)
plt.plot(X_outliers, lr.predict(X_outliers.reshape(-1,1)), color='green', label='Sem outliers')
plt.plot(X_outliers, y_est_outliers, color='red', label='Com outliers')
# plt.xlim(140, 200)
# plt.ylim(40, 250)
plt.legend(fontsize=12)

# %% [markdown]
# ### Resíduos
#
# Em termos gerais, trata-se dos erros da regressão.

# %%
residuos = y - y_est

# %%
residuos_outliers = y_outliers - y_est_outliers

# %% [markdown]
# ## Características dos Resíduos
#
# #### 1. Não devem ser correlacionados

# %% [markdown]
# #### Sem outliers

# %%
plt.scatter(y, residuos)

# %% [markdown]
# #### Com outliers

# %%
plt.scatter(y_outliers, residuos_outliers)

# %% [markdown]
# ### 2. Ter média zero

# %% [markdown]
# #### Sem outliers

# %%
np.mean(residuos)
# Out:
# 3.467448550509289e-14

# %% [markdown]
# #### Com outliers

# %%
np.mean(residuos_outliers)
# Out:
# 1.2969129545912509e-14

# %% [markdown]
# ### 4. Distribuição normal dos resíduos

# %% [markdown]
# #### Sem outliers

# %%
sns.histplot(residuos, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# #### Com outliers

# %%
sns.histplot(residuos_outliers, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Métricas para Análise dos Erros
#
# $$
# SQE = \sum_{i=1}^N \epsilon_i^2 = \frac{1}{N} \sum_{i=1}^N \left[y_i - \hat{y}_i\right]^2 = \frac{1}{N} \sum_{i=1}^N \left[y_i - (\beta_0 + \beta_1x_i)\right]^2
# $$
#
# $$
# SQT = \sum_{i=1}^N \left(\hat{y}_i - \overline{y}\right)^2
# $$
#
# $$
# SQExp = \sum_{i=1}^N \left(y_i - \overline{y}\right)^2
# $$

# %% [markdown]
# ### 1. R-Quadrado ($R^2$)
#
# Quanto mais "espalhados" estiverem os pontos em torno da reta, em geral **pior é o modelo**, pois ele está errando mais!
#
# Uma forma de quantificar isso através de uma métrica conhecida como **$R^2$**, o **coeficiente de determinação**.
#
# Este coeficiente indica **o quão próximos os dados estão da reta ajustada**. Por outro lado, o $R^2$ representa a porcentagem de variação na resposta que é explicada pelo modelo. Também conhecido como **percentual de variância explicada**.
#
# $$
# R^2 = 1 - \frac{SQE}{SQT} = \frac{SQT - SQExp}{SQT} = \frac{SQExp}{SQT}
# $$
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^n(y_i-\hat{y}_i)^2}{\sum_{i=1}^n(y_i-\bar{y})^2}
# $$
#
# > É possível utilizar o $R^2$ nos dados de treino, mas isso não é tão significante, devido ao *overfitting*, que discutiremos a seguir. Mais significativo é calcularmos o $R^2$ nos dados de teste como faremos a seguir.
#
# <img src="https://s3-sa-east-1.amazonaws.com/lcpi/13389132-5482-4e97-a00a-86a6b1ce9d4a.png" width=600 style="margin: 2rem auto; display: block;" />

# %%
lr.score(X.reshape(-1, 1), y)
# Out:
# 0.6214261131940761

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y, y_est)
# Out:
# 0.6214261131940761

# %%
# Com outliers
r2_score(y_outliers, y_est_outliers)
# Out:
# 0.00236489972361853

# %% [markdown]
# ### 2. MAE

# %%
from sklearn.metrics import mean_absolute_error as MAE

# %%
MAE(y, y_est)
# Out:
# 4.260493303495109

# %%
# Com outliers
MAE(y_outliers, y_est_outliers)
# Out:
# 9.640274384813585

# %% [markdown]
# ### 3. MSE

# %%
from sklearn.metrics import mean_squared_error as MSE

# %%
MSE(y, y_est)
# Out:
# 28.728718184843036

# %%
# Com outliers
MSE(y_outliers, y_est_outliers)
# Out:
# 460.66295293941755

# %% [markdown]
# ### 4. RMSE

# %%
np.sqrt(MSE(y, y_est))
# Out:
# 5.359917740492202

# %%
# Com outliers
np.sqrt(MSE(y_outliers, y_est_outliers))
# Out:
# 21.4630601951217

# %% [markdown]
# ### 5. RMSLE

# %%
from sklearn.metrics import mean_squared_log_error

# %%
np.sqrt(mean_squared_log_error(y, y_est))
# Out:
# 0.06297159962233727

# %%
np.sqrt(mean_squared_log_error(y_outliers, y_est_outliers))
# Out:
# 0.16715354395780962

# %% [markdown]
# ### Treino/Teste

# %%
from sklearn.model_selection import train_test_split

# %%
X = df['altura'].values
y = df['peso'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (7000,)

# %%
X_test.shape
# Out:
# (3000,)

# %%
y_train.shape
# Out:
# (7000,)

# %%
y_test.shape
# Out:
# (3000,)

# %%
len(train_test_split(X, y, test_size=0.3))
# Out:
# 4

# %%
lr = LinearRegression()

# %%
lr.fit(X_train.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([1.38054793])

# %%
lr.intercept_
# Out:
# -159.51336745328155

# %%
y_est = lr.predict(X_test.reshape(-1,1))

# %%
y_est[:5]
# Out:
# array([82.73166721, 60.66385986, 68.29654636, 65.44460923, 85.48697871])

# %%
y_test[:5]
# Out:
# array([74.22217815, 64.28224497, 66.8395327 , 68.61737153, 80.7357771 ])

# %%
r2_score(y_test, y_est)
# Out:
# 0.8572268074425229
