# %%
# Importação das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

# Bibliotecas para RL
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_validate
import statsmodels.api as sm
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

sns.set()
pio.templates.default = 'plotly_dark'

# %% [markdown]
# # Regressão Linear Múltipla
# ---
#
# ## Q1. Previsão do Saldo Médio do Cartão de Crédito
#
# <img src="https://selecao-stg.letscode.com.br/favicon.png" style="position: absolute; top: 0.75rem; right: 2rem; width: 50px" />
#
# Neste case, você deverá aplicar a regressão linear múltipla para estimar o saldo médido do cartão de crédito de clientes de um banco, a partir das demais informações contidas no conjunto de dados (`credit_regression.csv`), os quais são descritos abaixo. Aplique a regressão linear, utilizando o `LinearRegression` do `sklearn` e, também, o `OLS` do `statsmodels`.
#
# * ID - Identificação
# * Income - Renda
# * Limit - Limite de crédito
# * Rating - Score do Serasa
# * Age - Idade
# * Education - Anos de educação
# * Gender - Gênero
# * Student - É estudante? (Sim ou Não)
# * Married - É casado(a)? (Sim ou Não)
# * Ethnicity - Afro-americano, asiático ou branco
# * Balance - Saldo médio do cartão de crédito em dólares
#
# > [Link para o download do dataset](https://s3-sa-east-1.amazonaws.com/lcpi/ab0a9e91-89d1-4897-b384-51a86c50b804.csv)

# %%
# Carregando dataset
df = pd.read_csv('d2.csv')
df.head(3)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580

# %%
# Nenhuma é nula
# 4 categoricos
# Deamis são numericos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  400 non-null    int64
#  1   Income      400 non-null    float64
#  2   Limit       400 non-null    int64
#  3   Rating      400 non-null    int64
#  4   Cards       400 non-null    int64
#  5   Age         400 non-null    int64
#  6   Education   400 non-null    int64
#  7   Gender      400 non-null    object
#  8   Student     400 non-null    object
#  9   Married     400 non-null    object
#  10  Ethnicity   400 non-null    object
#  11  Balance     400 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
df.describe().T
# Out:
#             count         mean          std      min         25%        50%  \
# Unnamed: 0  400.0   200.500000   115.614301    1.000   100.75000   200.5000
# Income      400.0    45.218885    35.244273   10.354    21.00725    33.1155
# Limit       400.0  4735.600000  2308.198848  855.000  3088.00000  4622.5000
# Rating      400.0   354.940000   154.724143   93.000   247.25000   344.0000
# Cards       400.0     2.957500     1.371275    1.000     2.00000     3.0000
# Age         400.0    55.667500    17.249807   23.000    41.75000    56.0000
# Education   400.0    13.450000     3.125207    5.000    11.00000    14.0000
# Balance     400.0   520.015000   459.758877    0.000    68.75000   459.5000
#
#                    75%        max
# Unnamed: 0   300.25000    400.000
# Income        57.47075    186.634
# Limit       5872.75000  13913.000
# Rating       437.25000    982.000
# Cards          4.00000      9.000
# Age           70.00000     98.000
# Education     16.00000     20.000
# Balance      863.00000   1999.000

# %%
df.describe(include=['object'])
# Out:
#         Gender Student Married  Ethnicity
# count      400     400     400        400
# unique       2       2       2          3
# top     Female      No     Yes  Caucasian
# freq       207     360     245        199

# %%
# Matriz de correlação
df.corr()
# Out:
#             Unnamed: 0    Income     Limit    Rating     Cards       Age  \
# Unnamed: 0    1.000000  0.037203  0.024172  0.021985 -0.036304  0.058603
# Income        0.037203  1.000000  0.792088  0.791378 -0.018273  0.175338
# Limit         0.024172  0.792088  1.000000  0.996880  0.010231  0.100888
# Rating        0.021985  0.791378  0.996880  1.000000  0.053239  0.103165
# Cards        -0.036304 -0.018273  0.010231  0.053239  1.000000  0.042948
# Age           0.058603  0.175338  0.100888  0.103165  0.042948  1.000000
# Education    -0.001415 -0.027692 -0.023549 -0.030136 -0.051084  0.003619
# Balance       0.006064  0.463656  0.861697  0.863625  0.086456  0.001835
#
#             Education   Balance
# Unnamed: 0  -0.001415  0.006064
# Income      -0.027692  0.463656
# Limit       -0.023549  0.861697
# Rating      -0.030136  0.863625
# Cards       -0.051084  0.086456
# Age          0.003619  0.001835
# Education    1.000000 -0.008062
# Balance     -0.008062  1.000000

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
#Apenas numericos
df_numerico = df.select_dtypes(['int','float'])
df_numerico
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Balance
# 0             1   14.891   3606     283      2   34         11      333
# 1             2  106.025   6645     483      3   82         15      903
# 2             3  104.593   7075     514      4   71         11      580
# 3             4  148.924   9504     681      3   36         11      964
# 4             5   55.882   4897     357      2   68         16      331
# ..          ...      ...    ...     ...    ...  ...        ...      ...
# 395         396   12.096   4100     307      3   32         13      560
# 396         397   13.364   3838     296      5   65         17      480
# 397         398   57.872   4171     321      5   67         12      138
# 398         399   37.728   2525     192      1   44         13        0
# 399         400   18.701   5524     415      5   64          7      966
#
# [400 rows x 8 columns]

# %%
#Eliminar o Balance porque é o que queremos
#Eliminar o Limit pois é muito com o balance, acima de 85%
X1 = df_numerico.drop(columns=['Balance','Limit'])
Y1 = df_numerico['Balance']

# %%
#Fazer o Split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1,Y1,test_size=0.3,random_state=2)

#Treinar o modelo
lr1 = LinearRegression().fit(X1,Y1)

#Aplicar o Cross Validate
cross_validate(estimator=LinearRegression(),X=X_train1,y=y_train1,scoring='r2',
              return_train_score=True)

# %%
lr1 = LinearRegression().fit(X_train1, y_train1)

# %%
y_pred1 = lr1.predict(X_test1)

# %%
y_pred1[:5]
# Out:
# array([ 167.63382035,  673.47534905, 1007.12081613,  622.12475649,
#         959.70151287])

# %%
y_test1[:5]
# Out:
# 94        0
# 32      526
# 225    1075
# 157    1020
# 356     962
# Name: Balance, dtype: int64

# %%
resids1 = y_test1 - y_pred1
resids1
# Out:
# 94    -167.633820
# 32    -147.475349
# 225     67.879184
# 157    397.875244
# 356      2.298487
#           ...
# 175    -68.739643
# 99      58.649123
# 366     50.945601
# 362    -61.371475
# 10      62.731362
# Name: Balance, Length: 120, dtype: float64

# %%
def plot_resids(resids, y_true):
    plt.figure(figsize=(18,7))
    
    plt.subplot(1,2,1)
    plt.scatter(y_true, resids)
    
    plt.subplot(1,2,2)
    sns.histplot(resids, kde=True)

# %%
# Visivel um outlier, acima de 300, eixo Y
# Muitos zeros
plot_resids(resids1,y_test1)

# %%
#Novo modelo, tratando apenas os ativos

# %%
df_dummies = pd.get_dummies(df,drop_first=True)
df_dummies.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Balance  \
# 0           1   14.891   3606     283      2   34         11      333
# 1           2  106.025   6645     483      3   82         15      903
# 2           3  104.593   7075     514      4   71         11      580
# 3           4  148.924   9504     681      3   36         11      964
# 4           5   55.882   4897     357      2   68         16      331
#
#    Gender_Female  Student_Yes  Married_Yes  Ethnicity_Asian  \
# 0              0            0            1                0
# 1              1            1            1                1
# 2              0            0            0                1
# 3              1            0            0                1
# 4              0            0            1                0
#
#    Ethnicity_Caucasian
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
df_dummies['Active']=df['Balance'].map(lambda balance: 0 if balance ==0 else 1)
df_dummies.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Balance  \
# 0           1   14.891   3606     283      2   34         11      333
# 1           2  106.025   6645     483      3   82         15      903
# 2           3  104.593   7075     514      4   71         11      580
# 3           4  148.924   9504     681      3   36         11      964
# 4           5   55.882   4897     357      2   68         16      331
#
#    Gender_Female  Student_Yes  Married_Yes  Ethnicity_Asian  \
# 0              0            0            1                0
# 1              1            1            1                1
# 2              0            0            0                1
# 3              1            0            0                1
# 4              0            0            1                0
#
#    Ethnicity_Caucasian  Active
# 0                    1       1
# 1                    0       1
# 2                    0       1
# 3                    0       1
# 4                    1       1

# %%
X2 = df_dummies.drop(columns=['Balance'])
y2 = df_dummies['Balance']

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2,y2,test_size=0.3,random_state=2)

# %%
cross_validate(estimator=LinearRegression(),X=X_train2,y=y_train2,scoring='r2',
              return_train_score=True)
# Out:
# {'fit_time': array([0.00682878, 0.00200033, 0.00200033, 0.00200057, 0.00200033]),
#  'score_time': array([0.00100136, 0.00200105, 0.00100017, 0.0010004 , 0.00200009]),
#  'test_score': array([0.96734402, 0.96494766, 0.98428408, 0.96529854, 0.96266556]),
#  'train_score': array([0.97361715, 0.97407567, 0.96907429, 0.97434   , 0.97427005])}

# %%
lr2=LinearRegression().fit(X_train2,y_train2)
y_pred2=lr2.predict(X_test2)
resids2=y_test2-y_pred2

# %%
plot_resids(resids2,y_test2)

# %%
y_pred2[:5]
# Out:
# array([ 181.97113475,  535.42742846, 1029.18105417,  998.10169583,
#         975.51425707])

# %%
y_test2[:5].values
# Out:
# array([   0,  526, 1075, 1020,  962], dtype=int64)

# %% [markdown]
# ### Considerando apenas ativos, Balance !=0

# %%
X_active = df_dummies[df_dummies['Active']==1]
X_active.shape
# Out:
# (310, 14)

# %%
y_active = df_dummies[df_dummies['Balance']>0]['Balance']
y_active.shape
# Out:
# (310,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_active,y_active,random_state=2)

# %%
lr=LinearRegression().fit(X_train,y_train)
y_pred = lr.predict(X_test)
resids = y_test - y_pred

# %%
plot_resids(resids=resids,y_true=y_test)

# %% [markdown]
# ### Statsmodels

# %%
#############################

# %% [markdown]
# ### Classificando balance==0

# %%
df_dummies.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Balance  \
# 0           1   14.891   3606     283      2   34         11      333
# 1           2  106.025   6645     483      3   82         15      903
# 2           3  104.593   7075     514      4   71         11      580
# 3           4  148.924   9504     681      3   36         11      964
# 4           5   55.882   4897     357      2   68         16      331
#
#    Gender_Female  Student_Yes  Married_Yes  Ethnicity_Asian  \
# 0              0            0            1                0
# 1              1            1            1                1
# 2              0            0            0                1
# 3              1            0            0                1
# 4              0            0            1                0
#
#    Ethnicity_Caucasian  Active
# 0                    1       1
# 1                    0       1
# 2                    0       1
# 3                    0       1
# 4                    1       1

# %%
X = df_dummies.drop(columns=['Balance','Active'])
y = df_dummies['Active']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,roc_auc_score

# %%
X_train, X_test, y_train,y_test=train_test_split(X,y,random_state=2)
clf=LogisticRegression(solver='liblinear').fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  3],
#        [ 1, 80]], dtype=int64)

# %%
roc_auc_score(y_test,clf.predict_proba(X_test)[:,1])
# Out:
# 0.9948018193632229

# %% [markdown]
# ## Q2. Estimando o Preço de Venda de Casas
#
# O arquivo `usa_housing.csv` consiste em um dataset que contém informações sobre o preço de casas em determinadas regiões dos Estados Unidos. Uma descrição das colunas desse dataframes é apresentada abaixo:
#
# * `Avg. Area Income`: Média da renda dos residentes de onde a casa está localizada.
# * `Avg. Area House Age`: Média de idade das casas da mesma cidade.
# * `Avg. Area Number of Rooms`: Número médio de quartos para casas na mesma cidade.
# * `Avg. Area Number of Bedrooms`: Número médio de quartos para casas na mesma cidade.
# * `Area Population`: A população da cidade onde a casa está localizada.
# * `Price`: Preço de venda da casa.
# * `Address`: Endereço da casa.
#
# Utilize os dados contidos nele para criar um modelo de regressão linear que seja capaz de estimar o preço de venda das casas.
#
# > [Clique aqui](https://s3-sa-east-1.amazonaws.com/lcpi/7cf57d48-ac3d-4748-9d81-5b4d6677fcff.csv) para fazer o download do dataset.

# %%
# Carregando dataset
df1 = pd.read_csv('d1.csv')
df1.head(3)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...

# %%
#Em um ambiente amostral de 5000 a coluna endereço é muito especifica e será dropada para facilitar a analise
df1.shape
# Out:
# (5000, 7)

# %%
#Dropei pois eles são únicos e strings quase como um nome pessoal, não faz sentido eles
df1.drop(columns=['Address'], inplace =True)

#Tirar o target

# %% [markdown]
# ## Análise Exploratória dos Dados

# %%
sns.heatmap(df1.corr(), cmap='coolwarm', annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
#Eliminar o PRICE porque é o que queremos
X1 = df1.drop(columns=['Price'])
y1 = df1['Price']

# %%
#Split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.3, random_state=2)

#Cross Validate
cross_validate(estimator=LinearRegression(), X=X_train1, y=y_train1,\
               scoring='r2', return_train_score=True, cv=5)
# Out:
# {'fit_time': array([0.00173283, 0.00200152, 0.00099897, 0.00199986, 0.00100017]),
#  'score_time': array([0.00099969, 0.0010004 , 0.00100088, 0.00100017, 0.0010004 ]),
#  'test_score': array([0.91613382, 0.90981445, 0.91684268, 0.92090174, 0.91984342]),
#  'train_score': array([0.91734977, 0.91879227, 0.91721677, 0.91618572, 0.9164892 ])}

# %%
#Treinar o modelo
lr1 = LinearRegression().fit(X_train1, y_train1)

#Predições do modelo
y_pred1 = lr1.predict(X_test1)

#Cinco primeiras predições
print(f'{y_pred1[:5]}\n')

#Cinco primeiros do teste
print(f'{list(y_test1[:5])}')
# Out:
# [1295031.24675267 1766485.78728687 1060612.38913772 1329247.80003724
#   624969.88829953]
#
# [1197740.916766395, 1621035.9027174718, 1031367.588516485, 1414294.897975369, 616738.2083315281]

# %%
#Modelo plot
plt.plot(y_pred1,y_pred1,c="red")
plt.scatter(y_test1,y_pred1,s=1)

# %%
#Analise de Residuos
resids1 = y_test1 - y_pred1
plot_resids(resids1, y_test1)

# %%
#As casas tem em média um custo de 123mil 
#Um erro de 30mil é 25% do valor total da média e esse são erros outliers
df1['Price'].mean()
# Out:
# 1232072.65414236

# %%
#Fim
